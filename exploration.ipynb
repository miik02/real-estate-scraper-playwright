# %%
from playwright.sync_api import sync_playwright

# %%
def prueba():
    with sync_playwright() as p:
        browser = p.chromium.launch(headless=False, slow_mo=50)
        page = browser.new_page()

        # 2. Navegamos a la URL
        print("Entrando en la web...")
        page.goto("https://www.idealista.com/geo/venta-viviendas/metro-las-rosas/")

        casas = page.get_by_role("article")
        print(casas.count())
        browser.close()

# %%
prueba()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 prueba()
#
# Cell In[6], line 2, in prueba()
#       1 def prueba():
# ----> 2     with sync_playwright() as p:
#       3         browser = p.chromium.launch(headless=False, slow_mo=50)
#       4         page = browser.new_page()
#
# File ~/uni/ProyectosLinkedin/data_env/lib/python3.12/site-packages/playwright/sync_api/_context_manager.py:46, in PlaywrightContextManager.__enter__(self)
#      44             self._own_loop = True
#      45         if self._loop.is_running():
# ---> 46             raise Error(
#      47                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      48 Please use the Async API instead."""
#      49             )
#      51         # Create a new fiber for the protocol dispatcher. It will be pumping events
#      52         # until the end of times. We will pass control to that fiber every time we
#      53         # block while waiting for a response.
#      54         def greenlet_main() -> None:
#
# Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.
